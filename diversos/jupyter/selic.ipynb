# %%
# Pasta autal

import os

print(os.getcwd())
# Out:
# /home/hilaneto/Jhan/Trabalho/python/projetos/webapp/diversos/jupyter

# %%
import sys
import os

root = os.path.abspath(os.path.join(os.getcwd(), "../.."))

if root not in sys.path:
    sys.path.insert(0, root)

# %%
from database.conexao import conectar
from models.selic import Selic

with conectar():
    selic = Selic.atual()

print(selic.indice)
print(selic.status)
print(selic.dt_referencia)
print(selic.dt_atualizacao)
# Out:
# 14.00000
# True
# 2026-09-03
# 2026-09-03 19:30:06.012562-03:00
