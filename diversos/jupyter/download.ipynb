# %%
from pathlib import Path
from datetime import datetime

# class Download:
PASTA = Path("/home/hilaneto/Jhan/Pessoal/Pessoal/Curri/")

def listar():
    arquivos = []
    for arquivo in sorted(PASTA.iterdir()):
        if arquivo.is_file():
            arquivos.append({
                "nome": arquivo.name,
                "tamanho": arquivo.stat().st_size,
                "data": datetime.fromtimestamp(arquivo.stat().st_mtime).strftime("%d/%m/%Y %H:%M")
            })

    return arquivos

# %%
aaa = listar()

for i in aaa:
    print(i)
# Out:
# {'nome': 'CV_Bernadete_2026.pdf', 'tamanho': 281833, 'data': '21/01/2026 23:19'}
# {'nome': 'CV_JoseHilario.pdf', 'tamanho': 24125, 'data': '06/08/2026 12:15'}
# {'nome': 'Cv_Bernadete_2026 ok.docx', 'tamanho': 32739, 'data': '22/01/2026 12:13'}
# {'nome': 'Cv_Bernadete_2026.docx', 'tamanho': 31727, 'data': '22/01/2026 12:46'}
# {'nome': 'JoseHilario.docx', 'tamanho': 30605, 'data': '15/08/2025 17:46'}
# {'nome': 'JoseHilario_CV_Res.pdf', 'tamanho': 130125, 'data': '15/08/2025 12:42'}
# {'nome': 'JoseHilario_novo.docx', 'tamanho': 29686, 'data': '15/08/2025 17:46'}
# {'nome': 'JoseHilario_novo_Resumido.docx', 'tamanho': 28314, 'data': '15/08/2025 17:46'}
# {'nome': 'resumo.txt', 'tamanho': 1264, 'data': '23/03/2026 18:35'}

# %%
aaa
# Out:
# [{'nome': 'CV_Bernadete_2026.pdf',
#   'tamanho': 281833,
#   'data': '21/01/2026 23:19'},
#  {'nome': 'CV_JoseHilario.pdf', 'tamanho': 24125, 'data': '06/08/2026 12:15'},
#  {'nome': 'Cv_Bernadete_2026 ok.docx',
#   'tamanho': 32739,
#   'data': '22/01/2026 12:13'},
#  {'nome': 'Cv_Bernadete_2026.docx',
#   'tamanho': 31727,
#   'data': '22/01/2026 12:46'},
#  {'nome': 'JoseHilario.docx', 'tamanho': 30605, 'data': '15/08/2025 17:46'},
#  {'nome': 'JoseHilario_CV_Res.pdf',
#   'tamanho': 130125,
#   'data': '15/08/2025 12:42'},
#  {'nome': 'JoseHilario_novo.docx',
#   'tamanho': 29686,
#   'data': '15/08/2025 17:46'},
#  {'nome': 'JoseHilario_novo_Resumido.docx',
#   'tamanho': 28314,
#   'data': '15/08/2025 17:46'},
#  {'nome': 'resumo.txt', 'tamanho': 1264, 'data': '23/03/2026 18:35'}]
