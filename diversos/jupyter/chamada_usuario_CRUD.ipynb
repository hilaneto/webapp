# %% [markdown]
# ##### Local Jupyter

# %%
# Pasta autal

import os

print(os.getcwd())
# Out:
# /home/hilaneto/Jhan/Desenvolvimento/Python/vscode/BancoDados/peewee

# %% [markdown]
# #### Listar SQL Puro

# %%
from database.conexao import conectar

with conectar() as db:
    usuario = db.execute_sql( "SELECT * FROM tb_usuario;" ).fetchall()
    print(usuario)
# Out:
# [(3, 'bu', 'bu.alves', 'aaaa', 'bubu', 1, 'bu@yahoo.com', True, datetime.datetime(2026, 8, 2, 19, 43, 46, 409672)), (58, 'bug', 'bug', 'aaaa', '0020', 1, 'bug@gmail.com', True, datetime.datetime(2026, 8, 3, 11, 59, 4, 250335)), (32, 'cccc', 'cccc', 'aaaa', 'cccc', 1, 'cccc@peewee.com', False, datetime.datetime(2026, 8, 2, 19, 0, 6, 236821)), (66, 'pap', 'pap', 'pap', '0023', 1, 'pap@gmail.com', True, datetime.datetime(2026, 8, 4, 10, 15, 40, 732048)), (12, 'Hilaneto Alves Neto', 'hilario.alves', '6990', '064787', 1, 'jose@yahoo.com', True, datetime.datetime(2026, 8, 2, 1, 36, 4, 722762)), (43, 'Thays Pereira', 'thays', 'tata', '0101', 1, 'thays@gmail.com', True, datetime.datetime(2026, 8, 2, 16, 58, 4, 844834)), (65, 'Pupy_2', 'Pupy_2.alves', 'Pupy_2', 'Pupy_2', 1, 'Pupy_2@yahoo.com', False, datetime.datetime(2026, 8, 4, 11, 38, 6, 982429)), (45, 'Marina Pereira', 'marina', 'mama', '0303', 1, 'marina@gmail.com', True, datetime.datetime(2026, 8, 2, 17, 21, 48, 895643)), (67, 'BV_2', 'BV_2.alves', 'BV_2', 'BV_2', 1, 'BV_2@yahoo.com', False, datetime.datetime(2026, 8, 4, 11, 38, 23, 357605)), (41, 'eee', 'eee', 'eee', 'eee', 1, 'eee@peewee.com', False, datetime.datetime(2026, 8, 2, 17, 58, 50, 941813)), (44, 'mi mi lena', 'mimi.alves', 'mimi', 'mimi', 1, 'mimi@yahoo.com', True, datetime.datetime(2026, 8, 2, 19, 37, 13, 412559)), (55, 'Bernadete Pereira', 'vv', 'bebe', '0002', 1, 'be@gmail.com', True, datetime.datetime(2026, 8, 2, 19, 54, 5, 197851)), (56, 'hi', 'hi.alves', 'hi', '0005', 1, 'hi@yahoo.com', False, datetime.datetime(2026, 8, 2, 20, 6, 24, 275540)), (20, 'te', 'te.alves', 'ee', '15423', 1, 'te@yahoo.com', True, datetime.datetime(2026, 8, 2, 20, 7, 46, 696982)), (49, 'Bernadete Pereira', 'ba', 'bebe', '0000', 1, 'be@gmail.com', False, datetime.datetime(2026, 8, 2, 20, 24, 12, 146760)), (63, 'teste', 'teste', 'teste', 'teste', 1, None, True, datetime.datetime(2026, 8, 3, 16, 5, 14, 58880)), (37, 'ddd', 'ddd', 'ddd', 'ddd', 1, 'ddd@peewee.com', True, datetime.datetime(2026, 8, 2, 1, 30, 22, 848531)), (30, 'bbbb', 'bbbb', 'aaaa', 'bbbbb', 1, 'teste@peewee.com', True, datetime.datetime(2026, 8, 2, 18, 46, 52, 997154)), (52, 'Bernadete Pereira', 'bc', 'bebe', '0001', 1, 'be@gmail.com', True, datetime.datetime(2026, 8, 2, 19, 58, 19, 517098)), (57, 'beli', 'beli.alves', 'lilili', 'beli', 1, 'beli@yahoo.com', True, datetime.datetime(2026, 8, 3, 18, 7, 33, 174478)), (64, 'dic_2', 'dic_2.alves', 'dic_2', 'dic_2', 1, 'dic_2@yahoo.com', False, datetime.datetime(2026, 8, 3, 18, 54, 28, 55202))]

# %% [markdown]
# #### Inserir

# %%
from database.conexao import conectar
from database.crud_base import CrudBase
from peewee import IntegrityError

#from models.pessoa import CrudPessoa
from models.entidades import CrudUsuario

dados = {"nm_usuario": "Euro17",
        "email": "Euro17@gmail.com",
        "login": "Euro17",
        "senha": "Euro17",
        "cpf": "0025",
        "cd_permissao": 1,
        "fl_ativo": True}

with conectar():
    try:
        crud = CrudUsuario()
        usuario = crud.inserir(**dados)
        print(f"Usuário: {usuario.nm_usuario} inserido.")
    except TypeError as erro:
        print(f"Erro de tipo: {erro}")
    except IntegrityError as erro:
        print(f"Erro do PostgreSQL: {erro}")
# Out:
# Usuário: Euro17 inserido.

# %% [markdown]
# #### Buscar

# %%
from database.conexao import conectar
from database.crud_base import CrudBase

#from models.pessoa import CrudPessoa
from models.entidades import CrudUsuario

busca = {'nm_usuario': 'Euro17'}
#busca = {}

with conectar():
    crud = CrudUsuario()
    usuarios = crud.buscar(**busca)
    for usuario in usuarios:
        print(usuario.__data__)
# Out:
# {'cd_usuario': 68, 'nm_usuario': 'Euro17', 'login': 'Euro17', 'senha': 'Euro17', 'cpf': '0025', 'cd_permissao': 1, 'email': 'Euro17@gmail.com', 'fl_ativo': True, 'dt_atualizacao': datetime.datetime(2026, 8, 5, 13, 34, 57, 764613)}

# %% [markdown]
# #### Gerando Dataframe Pandas

# %%
from database.conexao import conectar
from database.crud_base import CrudBase

#from models.pessoa import CrudPessoa
from models.entidades import CrudUsuario

import pandas as pd

busca = {'cpf': 'Euro17'}
#busca = {}

with conectar():
    crud = CrudUsuario()
    usuarios = crud.buscar(**busca)
    df = pd.DataFrame(list(usuarios.dicts()))
    
df
# Out:
#    cd_usuario nm_usuario          login    senha     cpf  cd_permissao  \
# 0          68    Euro_20  Euro_20.alves  Euro_20  Euro17             1
#
#                email  fl_ativo             dt_atualizacao
# 0  Euro_20@yahoo.com      True 2026-08-05 13:37:09.222680

# %% [markdown]
# #### Buscar Data

# %%
from database.conexao import conectar
from database.crud_base import CrudBase

#from models.pessoa import CrudPessoa
from models.entidades import CrudUsuario


#busca = { "data_inicial": date(2026, 8, 2)}

busca = { "data_inicial": date(2026, 8, 3), "data_final": date(2026, 8, 3)}

with conectar():
    crud = CrudUsuario()
    usuarios = crud.buscar_periodo(busca)
    for usuario in usuarios:
        print(usuario.__data__)
# Out:
# {'cd_usuario': 58, 'nm_usuario': 'bug', 'login': 'bug', 'senha': 'aaaa', 'cpf': '0020', 'cd_permissao': 1, 'email': 'bug@gmail.com', 'fl_ativo': True, 'dt_atualizacao': datetime.datetime(2026, 8, 3, 11, 59, 4, 250335)}
# {'cd_usuario': 63, 'nm_usuario': 'teste', 'login': 'teste', 'senha': 'teste', 'cpf': 'teste', 'cd_permissao': 1, 'email': None, 'fl_ativo': True, 'dt_atualizacao': datetime.datetime(2026, 8, 3, 16, 5, 14, 58880)}
# {'cd_usuario': 57, 'nm_usuario': 'beli', 'login': 'beli.alves', 'senha': 'lilili', 'cpf': 'beli', 'cd_permissao': 1, 'email': 'beli@yahoo.com', 'fl_ativo': True, 'dt_atualizacao': datetime.datetime(2026, 8, 3, 18, 7, 33, 174478)}
# {'cd_usuario': 64, 'nm_usuario': 'dic_2', 'login': 'dic_2.alves', 'senha': 'dic_2', 'cpf': 'dic_2', 'cd_permissao': 1, 'email': 'dic_2@yahoo.com', 'fl_ativo': False, 'dt_atualizacao': datetime.datetime(2026, 8, 3, 18, 54, 28, 55202)}

# %% [markdown]
# #### Alterar

# %%
from database.conexao import conectar
from database.crud_base import CrudBase

#from models.pessoa import CrudPessoa
from models.entidades import CrudUsuario

filtros = {'nm_usuario': 'Euro17'}

dados = {"nm_usuario": "Euro_20",
        "email": "Euro_20@yahoo.com",
        "login": "Euro_20.alves",
        "senha": "Euro_20",
        "cpf": "Euro17",
        "cd_permissao": 1,
        "fl_ativo": True}

with conectar():
    crud = CrudUsuario()
    linhas = crud.alterar(filtros, **dados)
    print(f"{linhas} registro(s) atualizado(s)")
# Out:
# 1 registro(s) atualizado(s)

# %% [markdown]
# #### Contar

# %%
from database.conexao import conectar
from database.crud_base import CrudBase

#from models.pessoa import CrudPessoa
from models.entidades import CrudUsuario

with conectar():
    crud = CrudUsuario()
    total = crud.contar(fl_ativo=False)
    print(total)
# Out:
# 8

# %% [markdown]
# #### Desativar

# %%
from database.conexao import conectar
from database.crud_base import CrudBase

#from models.pessoa import CrudPessoa
from models.entidades import CrudUsuario

busca = {'cpf': 'Euro17'}

with conectar():
    crud = CrudUsuario()
    linhas = crud.desativar(**busca)
    if linhas:
        print(f"{linhas} registro(s) desativado(s) com sucesso.")
    else:
        print("Registro não encontrado.")
# Out:
# 1 registro(s) desativado(s) com sucesso.
