# %%
# Pasta autal
import requests
import os

print(os.getcwd())
# Out:
# /home/hilaneto/Jhan/Trabalho/python/projetos/webapp/diversos/jupyter

# %%
import sys
import os

root = os.path.abspath(os.path.join(os.getcwd(), "../.."))

if root not in sys.path:
    sys.path.insert(0, root)

# %%
url = "https://webapp.jhan.com.br/cpf/06478701859"
resposta = requests.get(url)
resposta.json()

# %%
url = "https://webapp.jhan.com.br/cnpj/52268829000173"
resposta = requests.get(url)
resposta.json()

# %%
url = "https://webapp.jhan.com.br/cdusuario/3"
resposta = requests.get(url)
resposta.json()

# %%
from database.conexao import conectar
from models.usuario import Usuario

cdusuario = 6

with conectar():
    usuario = Usuario.buscar_cdusuario(cdusuario)
    print(usuario.login)
# Out:
# be
